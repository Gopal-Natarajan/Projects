# %%
! pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id = "842d4b23729f4905b8cef9328b69594f", client_secret= "b54f7b3b5c074b5ab4cb9029b8831c13")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF"

# %%
playlist_uri = playlist_link.split("/")[-1]

# %%
playlist_uri
# Out:
# '37i9dQZEVXbMDoHDwVN2tF'

# %%
data = sp.playlist_tracks(playlist_uri)

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbMDoHDwVN2tF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-08-21T09:58:14Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
# ...

# %%
#going to extract the album data

data['items'][0]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
# ...

# %%
data['items'][0]['track']['album']["id"]
# Out:
# '7aJuG4TFXa2hmE4z1yxc3n'

# %%
data['items'][0]['track']['album']["name"]
# Out:
# 'HIT ME HARD AND SOFT'

# %%
data['items'][0]['track']['album']["release_date"]
# Out:
# '2024-05-17'

# %%
data['items'][0]['track']['album']["total_tracks"]
# Out:
# 10

# %%
data['items'][0]['track']['album']["external_urls"]['spotify']
# Out:
# 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'

# %%
# we need all 50 songs album data. so, going to run the code in loop

# %%
album_list = []

for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']["release_date"]
    album_total_track = row['track']['album']['total_tracks']
    album_external_url = row['track']['album']['external_urls']['spotify']
    album_element = {
        'album_id': album_id, 'name': album_name, "release_date" : album_release_date, "total_track" : album_total_track, 
        "external_url" : album_external_url
        }
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_track': 10,
#   'external_url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '15XcLhiVMlSOipUddTNDnr',
#   'name': 'MUSE',
#   'release_date': '2024-07-19',
#   'total_track': 7,
#   'external_url': 'https://open.spotify.com/album/15XcLhiVMlSOipUddTNDnr'},
#  {'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'name': 'Die With A Smile',
#   'release_date': '2024-08-16',
#   'total_track': 1,
#   'external_url': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#  {'album_id': '5quMTd5zeI9yW5UDua8wS4',
#   'name': 'Espresso',
#   'release_date': '2024-04-12',
#   'total_track': 1,
#   'external_url': 'https://open.spotify.com/album/5quMTd5zeI9yW5UDua8wS4'},
#  {'album_id': '5ylbxH7EqpsmHZCRuiYewS',
#   'name': 'Si Antes Te Hubiera Conocido',
#   'release_date': '2024-06-21',
#   'total_track': 1,
# ...

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#   'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#   'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'name': 'Billie Eilish',
#   'type': 'artist',
#   'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}]

# %%
data['items'][0]['track']['artists']['id']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 data['items'][0]['track']['artists']['id']
#
# TypeError: list indices must be integers or slices, not str

# %%
# we have list of artists. it's a nested json. that's the reason we got the error, when we get a artist id. 
data['items'][5]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7GlBOeep6PqTfFi59PTUUN'},
#   'href': 'https://api.spotify.com/v1/artists/7GlBOeep6PqTfFi59PTUUN',
#   'id': '7GlBOeep6PqTfFi59PTUUN',
#   'name': 'Chappell Roan',
#   'type': 'artist',
#   'uri': 'spotify:artist:7GlBOeep6PqTfFi59PTUUN'}]

# %%
data['items'][0]
# Out:
# {'added_at': '2024-08-21T09:58:14Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
# ...

# %%
for row in data['items']:
    for key,value in row.items():
        if key == 'track':
            for artist in value['artists']:
                print(artist)
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'}, 'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH', 'id': '6qqNVTkY8uBg9cP3Jd7DAH', 'name': 'Billie Eilish', 'type': 'artist', 'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/1oSPZhvZMIrWW5I41kPkkY'}, 'href': 'https://api.spotify.com/v1/artists/1oSPZhvZMIrWW5I41kPkkY', 'id': '1oSPZhvZMIrWW5I41kPkkY', 'name': 'Jimin', 'type': 'artist', 'uri': 'spotify:artist:1oSPZhvZMIrWW5I41kPkkY'}
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'}, 'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms', 'id': '1HY2Jd0NmPuamShAr6KMms', 'name': 'Lady Gaga', 'type': 'artist', 'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}
# ...

# %%
artist_data = []

for row in data['items']:
    for key,value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict = {'artist_id' : artist['id'], 'artist_name': artist['name'],
                 'external_url' : artist['href']}

                artist_data.append(artist_dict)

# %%
artist_data
# Out:
# [{'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '1oSPZhvZMIrWW5I41kPkkY',
#   'artist_name': 'Jimin',
#   'external_url': 'https://api.spotify.com/v1/artists/1oSPZhvZMIrWW5I41kPkkY'},
#  {'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'external_url': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '790FomKkXshlbRYZFtlgla',
#   'artist_name': 'KAROL G',
#   'external_url': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla'},
#  {'artist_id': '7GlBOeep6PqTfFi59PTUUN',
# ...

# %%
data['items'][0]['track']
# Out:
# {'preview_url': None,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
# ...

# %%
song_data = []

for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_populariy = row['track']['popularity']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    album_id = row['track']['album']['id']
    artist_id = row['track']['artists'][0]['id']

    song_dict = {
        "song_id" : song_id, 'song_name':song_name,
        'popularity' : song_populariy, "duration" : song_duration, 'external_url' : song_url,
        'album_id' : album_id, 'artist_id' : artist_id
    }

    song_data.append(song_dict)

# %%
song_data
# Out:
# [{'song_id': '6dOtVTDdiauQNBQEDOtlAB',
#   'song_name': 'BIRDS OF A FEATHER',
#   'popularity': 100,
#   'duration': 210373,
#   'external_url': 'https://open.spotify.com/track/6dOtVTDdiauQNBQEDOtlAB',
#   'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'song_id': '7tI8dRuH2Yc6RuoTjxo4dU',
#   'song_name': 'Who',
#   'popularity': 95,
#   'duration': 170887,
#   'external_url': 'https://open.spotify.com/track/7tI8dRuH2Yc6RuoTjxo4dU',
#   'album_id': '15XcLhiVMlSOipUddTNDnr',
#   'artist_id': '1oSPZhvZMIrWW5I41kPkkY'},
#  {'song_id': '2plbrEY59IikOBgBGLjaoe',
#   'song_name': 'Die With A Smile',
#   'popularity': 85,
#   'duration': 251667,
#   'external_url': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe',
#   'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'artist_id': '1HY2Jd0NmPuamShAr6KMms'},
#  {'song_id': '2qSkIjg1o9h3YT9RAgYN75',
#   'song_name': 'Espresso',
#   'popularity': 98,
#   'duration': 175459,
# ...

# %%
import pandas as pd
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                          name release_date  \
# 0  7aJuG4TFXa2hmE4z1yxc3n          HIT ME HARD AND SOFT   2024-05-17
# 1  15XcLhiVMlSOipUddTNDnr                          MUSE   2024-07-19
# 2  10FLjwfpbxLmW8c25Xyc2N              Die With A Smile   2024-08-16
# 3  5quMTd5zeI9yW5UDua8wS4                      Espresso   2024-04-12
# 4  5ylbxH7EqpsmHZCRuiYewS  Si Antes Te Hubiera Conocido   2024-06-21
#
#    total_track                                       external_url
# 0           10  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 1            7  https://open.spotify.com/album/15XcLhiVMlSOipU...
# 2            1  https://open.spotify.com/album/10FLjwfpbxLmW8c...
# 3            1  https://open.spotify.com/album/5quMTd5zeI9yW5U...
# 4            1  https://open.spotify.com/album/5ylbxH7EqpsmHZC...

# %%
artist_df = pd.DataFrame.from_dict(artist_data)
artist_df.head()
# Out:
#                 artist_id        artist_name  \
# 0  6qqNVTkY8uBg9cP3Jd7DAH      Billie Eilish
# 1  1oSPZhvZMIrWW5I41kPkkY              Jimin
# 2  1HY2Jd0NmPuamShAr6KMms          Lady Gaga
# 3  0du5cEVh5yTK9QJze8zA0C         Bruno Mars
# 4  74KM79TiuVKeVCqs8QtB0B  Sabrina Carpenter
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/6qqNVTkY8uB...
# 1  https://api.spotify.com/v1/artists/1oSPZhvZMIr...
# 2  https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 3  https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 4  https://api.spotify.com/v1/artists/74KM79TiuVK...

# %%
song_df = pd.DataFrame.from_dict(song_data)
song_df.head()
# Out:
#                   song_id                     song_name  popularity  duration  \
# 0  6dOtVTDdiauQNBQEDOtlAB            BIRDS OF A FEATHER         100    210373
# 1  7tI8dRuH2Yc6RuoTjxo4dU                           Who          95    170887
# 2  2plbrEY59IikOBgBGLjaoe              Die With A Smile          85    251667
# 3  2qSkIjg1o9h3YT9RAgYN75                      Espresso          98    175459
# 4  6WatFBLVB0x077xWeoVc2k  Si Antes Te Hubiera Conocido          96    195824
#
#                                         external_url                album_id  \
# 0  https://open.spotify.com/track/6dOtVTDdiauQNBQ...  7aJuG4TFXa2hmE4z1yxc3n
# 1  https://open.spotify.com/track/7tI8dRuH2Yc6Ruo...  15XcLhiVMlSOipUddTNDnr
# 2  https://open.spotify.com/track/2plbrEY59IikOBg...  10FLjwfpbxLmW8c25Xyc2N
# 3  https://open.spotify.com/track/2qSkIjg1o9h3YT9...  5quMTd5zeI9yW5UDua8wS4
# 4  https://open.spotify.com/track/6WatFBLVB0x077x...  5ylbxH7EqpsmHZCRuiYewS
#
#                 artist_id
# ...

# %%
album_df.shape
# Out:
# (50, 5)

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_track   50 non-null     int64
#  4   external_url  50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      46 non-null     object
#  1   name          46 non-null     object
#  2   release_date  46 non-null     datetime64[ns]
#  3   total_track   46 non-null     int64
#  4   external_url  46 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.2+ KB

# %%
artist_df
# Out:
#                  artist_id         artist_name  \
# 0   6qqNVTkY8uBg9cP3Jd7DAH       Billie Eilish
# 1   1oSPZhvZMIrWW5I41kPkkY               Jimin
# 2   1HY2Jd0NmPuamShAr6KMms           Lady Gaga
# 3   0du5cEVh5yTK9QJze8zA0C          Bruno Mars
# 4   74KM79TiuVKeVCqs8QtB0B   Sabrina Carpenter
# ..                     ...                 ...
# 64  0jPHHnU8GUWEF7rwPE9osY     Jordan Adetunji
# 65  4V8LLVI7PbaPR0K2TGSxFF  Tyler, The Creator
# 66  1U1el3k54VvEUzo3ybLPlM          Kali Uchis
# 67  1Cs0zKBU1kc0i8ypK3B9ai        David Guetta
# 68  5Pwc4xIPtQLFEnJriah9YJ         OneRepublic
#
#                                          external_url
# 0   https://api.spotify.com/v1/artists/6qqNVTkY8uB...
# 1   https://api.spotify.com/v1/artists/1oSPZhvZMIr...
# 2   https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 3   https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 4   https://api.spotify.com/v1/artists/74KM79TiuVK...
# ..                                                ...
# ...

# %%
artist_df.shape
# Out:
# (69, 3)

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     69 non-null     object
#  1   artist_name   69 non-null     object
#  2   external_url  69 non-null     object
# dtypes: object(3)
# memory usage: 1.7+ KB

# %%
artist_df.duplicated().sum()
# Out:
# 12

# %%
artist_df.drop_duplicates(inplace = True)

# %%
artist_df.duplicated().sum()
# Out:
# 0

# %%
song_df
# Out:
#                    song_id                                          song_name  \
# 0   6dOtVTDdiauQNBQEDOtlAB                                 BIRDS OF A FEATHER
# 1   7tI8dRuH2Yc6RuoTjxo4dU                                                Who
# 2   2plbrEY59IikOBgBGLjaoe                                   Die With A Smile
# 3   2qSkIjg1o9h3YT9RAgYN75                                           Espresso
# 4   6WatFBLVB0x077xWeoVc2k                       Si Antes Te Hubiera Conocido
# 5   0WbMK4wrZ1wFSty9F7FCgu                                   Good Luck, Babe!
# 6   5N3hjp1WNayUPZrA8kJmJP                               Please Please Please
# 7   0OA00aPt3BV10qeMIs3meW                                          Big Dawgs
# 8   3xkHsmpQCBMytMJNiDf3Ii                                   Beautiful Things
# 9   5IZXB5IKAD2qlvTPJYDCFB              I Had Some Help (Feat. Morgan Wallen)
# 10  7qbJ4Dh8xuYUFdAWL8SFPK                      Guess featuring Billie Eilish
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   song_id       50 non-null     object
#  1   song_name     50 non-null     object
#  2   popularity    50 non-null     int64
#  3   duration      50 non-null     int64
#  4   external_url  50 non-null     object
#  5   album_id      50 non-null     object
#  6   artist_id     50 non-null     object
# dtypes: int64(2), object(5)
# memory usage: 2.9+ KB

# %%
song_df.duplicated().sum()
# Out:
# 0
